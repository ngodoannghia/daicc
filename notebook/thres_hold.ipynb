# %%
import pandas as pd 
import numpy as np

# %%
### Load label
labels = pd.read_csv("../data/label.csv")

### load data
data = pd.read_csv("../data/sensor_log.csv")

# %%
blockid_train = labels['block_id'].values

# %%
_train = data['block_id'].isin(blockid_train)
data_train = data[_train]
data_test = data[~_train]

# %%
data_test.describe()
# Out:
#             block_id      sensor_00      sensor_01      sensor_02  \
# count  135020.000000  135020.000000  135020.000000  135020.000000
# mean     9716.261887       2.460180      48.183664      51.767277
# std      5556.307170       0.056556       2.291089       1.613581
# min         0.000000       0.000000      37.065970      42.317710
# 25%      4972.000000       2.448669      46.527770      50.781250
# 50%      9711.500000       2.459491      48.263885      51.866320
# 75%     14333.000000       2.500810      49.739580      52.951385
# max     19282.000000       2.562369      56.510410      56.032990
#
#            sensor_03      sensor_04      sensor_05      sensor_06  \
# count  135020.000000  135020.000000  135020.000000  135020.000000
# mean       44.184143     633.081473      75.758804      13.956792
# std         1.592605      11.711798       6.984271       0.682740
# min        34.982640       3.104745       0.000000       0.014468
# ...

# %%
data_train.describe()
# Out:
#            block_id     sensor_00     sensor_01     sensor_02     sensor_03  \
# count  57810.000000  57810.000000  57810.000000  57810.000000  57810.000000
# mean    9465.219685      2.456694     48.083454     51.844648     44.325667
# std     5586.456770      0.058112      1.754239      1.535984      1.440665
# min      144.000000      0.000000     38.368050     42.838540     35.807290
# 25%     4479.000000      2.448669     47.135410     50.781250     43.446180
# 50%     9260.000000      2.455556     48.220490     51.822910     44.444443
# 75%    14683.000000      2.500810     49.262150     52.907990     45.355900
# max    18709.000000      2.585285     60.237007     55.425350     47.916664
#
#           sensor_04     sensor_05     sensor_06     sensor_07     sensor_08  \
# count  57810.000000  57810.000000  57810.000000  57810.000000  57810.000000
# mean     632.846089     75.649145     13.911208     16.142101     15.464119
# ...

# %%
data_train[data_train['sensor_01'] > 55]
# Out:
#                 timestamp  block_id  sensor_00  sensor_01  sensor_02  \
# 6774  2018-04-05 18:04:00       677   2.444734  58.792709   52.60416
# 6775  2018-04-05 18:05:00       677   2.459491  60.237007   52.73437
#
#       sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  sensor_08  \
# 6774   44.35764   630.3241   76.35315   13.38976   16.16753   15.56713
# 6775   44.44444   638.1945   78.20327   13.28848   16.16753   15.26331
#
#       sensor_09
# 6774   15.08247
# 6775   15.11863

# %%
labels[labels['block_id'] == 17272]
# Out:
#       block_id  anomalous
# 5346     17272          0

# %%
block_ids = []

# %%
block_ids += np.unique(data_test[data_test['sensor_00'] < 2.0]['block_id'].values).tolist()
block_ids += np.unique(data_test[data_test['sensor_04'] < 550]['block_id'].values).tolist()
block_ids += np.unique(data_test[data_test['sensor_05'] < 50]['block_id'].values).tolist()
block_ids += np.unique(data_test[data_test['sensor_06'] < 11]['block_id'].values).tolist()
block_ids += np.unique(data_test[data_test['sensor_07'] < 14]['block_id'].values).tolist()
block_ids += np.unique(data_test[data_test['sensor_09'] < 14]['block_id'].values).tolist()

# %%
result = list(set(block_ids))

# %%
import json 

with open('../analysis/block_id_anmolous.json', 'w') as f:
    json.dump(result, f)
